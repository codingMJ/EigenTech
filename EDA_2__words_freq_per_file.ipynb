# %% [markdown]
# ### Description:
# In this notebook, my goal is to do some EDA on count of tokens found in each file. <br>
#
# In **Stage 1: Import data**:<br>
# I just import processed data I did in notebook **EDA_1_...** which has 4 columns: **FileName**, **Sentence**,
# **Clean sentence**, **Lemmatized**.<br>
#
#
#
# In **Stage 2: Observe token frequencies**:<br>
# For each of six files, I get counts of unique tokens and explore them using bar charts.<br>
# I explore unique tokens counts from preprocessed columns **Clean sentence** and **Lemmatized**

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from gensim.parsing.preprocessing import STOPWORDS
from wordcloud import WordCloud, ImageColorGenerator  #STOPWORDS

# %% [markdown]
# ### Stage1: Import processed data

# %%
# 1
# Import data
df = pd.read_csv("Processed_data.csv")

# 2
# Remove rows containing NaN
df = df[df['Clean sentence'].notnull()]

# 3
# Check data
print("DF shape:", df.shape)
df.head()
# Out:
# DF shape: (935, 4)
#    FileName                                           Sentence  \
# 0  doc1.txt  Let me begin by saying thanks to all you who'v...
# 1  doc1.txt             We all made this journey for a reason.
# 2  doc1.txt  It's humbling, but in my heart I know you didn...
# 3  doc1.txt  In the face of war, you believe there can be p...
# 4  doc1.txt  In the face of despair, you believe there can ...
#
#                                       Clean sentence  \
# 0  let me begin thanks traveled far wide brave co...
# 1                                     journey reason
# 2  humbling heart i know come me came believe cou...
# 3                             face war believe peace
# 4                          face despair believe hope
#
#                                           Lemmatized
# 0  let i begin thank travel far wide brave cold t...
# 1                                     journey reason
# 2    humble heart i know come i come believe country
# 3                             face war believe peace
# 4                          face despair believe hope

# %% [markdown]
# ### Stage 2: Obeserve token frequencies

# %% [markdown]
# ### Get tokens ferquencies in doc1.txt

# %%
f = "doc1.txt"

for c in ["Clean sentence", "Lemmatized"]:
    proc_tokens = []
    for s in df.loc[df.FileName==f, c].tolist():
        proc_tokens.extend(s.split())

    # 5
    # Sort token counts in desc order
    term2freq = Counter(proc_tokens).most_common()

    # 6.1
    # Get top N common tokens
    s = 60
    tokens_ = [t for t,c in term2freq[:s]]
    counts_ = [c for t,c in term2freq[:s]]

    # 6.2
    # Plot bar chart
    y = range(len(tokens_))
    plt.figure(figsize=(18,5))           # option to configure chrat size, this line should come first
    plt.bar(y, counts_)
    plt.title(f)
    plt.xticks(y, tokens_, rotation=60)  # option to rotate bar names
    plt.show()

# %% [markdown]
# ### Get tokens ferquencies in doc2.txt

# %%
f = "doc2.txt"

for c in ["Clean sentence", "Lemmatized"]:
    proc_tokens = []
    for s in df.loc[df.FileName==f, c].tolist():
        proc_tokens.extend(s.split())

    # 5
    # Sort token counts in desc order
    term2freq = Counter(proc_tokens).most_common()

    # 6.1
    # Get top N common tokens
    s = 60
    tokens_ = [t for t,c in term2freq[:s]]
    counts_ = [c for t,c in term2freq[:s]]

    # 6.2
    # Plot bar chart
    y = range(len(tokens_))
    plt.figure(figsize=(18,5))           # option to configure chrat size, this line should come first
    plt.bar(y, counts_)
    plt.title(f)
    plt.xticks(y, tokens_, rotation=60)  # option to rotate bar names
    plt.show()

# %% [markdown]
# ### Get tokens ferquencies in doc3.txt

# %%
f = "doc3.txt"

for c in ["Clean sentence", "Lemmatized"]:
    proc_tokens = []
    for s in df.loc[df.FileName==f, c].tolist():
        proc_tokens.extend(s.split())

    # 5
    # Sort token counts in desc order
    term2freq = Counter(proc_tokens).most_common()

    # 6.1
    # Get top N common tokens
    s = 60
    tokens_ = [t for t,c in term2freq[:s]]
    counts_ = [c for t,c in term2freq[:s]]

    # 6.2
    # Plot bar chart
    y = range(len(tokens_))
    plt.figure(figsize=(18,5))           # option to configure chrat size, this line should come first
    plt.bar(y, counts_)
    plt.title(f)
    plt.xticks(y, tokens_, rotation=60)  # option to rotate bar names
    plt.show()

# %% [markdown]
# ### Get tokens ferquencies in doc5.txt

# %%
f = "doc4.txt"

for c in ["Clean sentence", "Lemmatized"]:
    proc_tokens = []
    for s in df.loc[df.FileName==f, c].tolist():
        proc_tokens.extend(s.split())

    # 5
    # Sort token counts in desc order
    term2freq = Counter(proc_tokens).most_common()

    # 6.1
    # Get top N common tokens
    s = 60
    tokens_ = [t for t,c in term2freq[:s]]
    counts_ = [c for t,c in term2freq[:s]]

    # 6.2
    # Plot bar chart
    y = range(len(tokens_))
    plt.figure(figsize=(18,5))           # option to configure chrat size, this line should come first
    plt.bar(y, counts_)
    plt.title(f)
    plt.xticks(y, tokens_, rotation=60)  # option to rotate bar names
    plt.show()

# %%
f = "doc5.txt"

for c in ["Clean sentence", "Lemmatized"]:
    proc_tokens = []
    for s in df.loc[df.FileName==f, c].tolist():
        proc_tokens.extend(s.split())

    # 5
    # Sort token counts in desc order
    term2freq = Counter(proc_tokens).most_common()

    # 6.1
    # Get top N common tokens
    s = 60
    tokens_ = [t for t,c in term2freq[:s]]
    counts_ = [c for t,c in term2freq[:s]]

    # 6.2
    # Plot bar chart
    y = range(len(tokens_))
    plt.figure(figsize=(18,5))           # option to configure chrat size, this line should come first
    plt.bar(y, counts_)
    plt.title(f)
    plt.xticks(y, tokens_, rotation=60)  # option to rotate bar names
    plt.show()

# %% [markdown]
# ### Get tokens ferquencies in doc6.txt

# %%
f = "doc6.txt"

for c in ["Clean sentence", "Lemmatized"]:
    proc_tokens = []
    for s in df.loc[df.FileName==f, c].tolist():
        proc_tokens.extend(s.split())

    # 5
    # Sort token counts in desc order
    term2freq = Counter(proc_tokens).most_common()

    # 6.1
    # Get top N common tokens
    s = 60
    tokens_ = [t for t,c in term2freq[:s]]
    counts_ = [c for t,c in term2freq[:s]]

    # 6.2
    # Plot bar chart
    y = range(len(tokens_))
    plt.figure(figsize=(18,5))           # option to configure chrat size, this line should come first
    plt.bar(y, counts_)
    plt.title(f)
    plt.xticks(y, tokens_, rotation=60)  # option to rotate bar names
    plt.show()
